# %% [markdown]
# ## 1.0 - Importing libraries

# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import ADASYN
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
import numpy as np
from sklearn.metrics import balanced_accuracy_score
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
import xgboost as xgb
from sklearn.metrics import confusion_matrix

warnings.filterwarnings('ignore') 
pd.option_context('display.max_rows', None)
sns.set(style="whitegrid")

# %% [markdown]
# ## 2.0 - Data Reading

# %%
infutor_dataset = pd.read_csv('../infutor_enrichment_dataset.csv', sep=',')
leads_dataset = pd.read_csv('../leads_dataset.csv', sep=',')
zip_code_dataset = pd.read_csv('../zip_code_dataset.csv', sep=',')

leads_dataset = leads_dataset.dropna(subset=['IS_APPOINTMENT_SET'])

# %%
infutor_dataset
# Out:
#         Unnamed: 0                       HASHED_PHONE_NUMBER  MATCHLEVEL  \
# 0                0  9a99e383ee68a51c2740de9883f5b1bee5d2a4da           1
# 1                1  0020b0a911711b66c100d7e8e25e226783bb0072           5
# 2                2  d436912ed29db2950ca13b64cc56fefc0f581f7a           1
# 3                3  c2bd44a987bc7b9663352235ea2b7bb04b696697           5
# 4                4  c363fb2c7bbdd728928716b4d5b4a80a13cbd2f2           1
# ...            ...                                       ...         ...
# 178576      178576  49eabc5f57579b3801bce715ac80996bb3e6d3ea           1
# 178577      178577  26f0b4294af5bb517a77476e430a36726f82341d           1
# 178578      178578  c630cac86df02fe941a01de6410c1391025daf22           1
# 178579      178579  2a6b007a4eecf61b1ed6cf328c75ff2f7e4d73b6           1
# 178580      178580  6dd46e30ce5096cce3ddaa76d0bd336b09bc1dc6           1
#
#        ATTRIBUTES_CONNEXSEGMENTATION_CT_HOMEIMPROVE12_ANY  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 178576                                                NaN
# 178577                                                NaN
# 178578                                                NaN
# 178579                                                  Y
# 178580                                                  Y
#
#        ATTRIBUTES_CONNEXSEGMENTATION_CT_HOMEREMODEL12_ANY  \
# 0                                                       Y
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 178576                                                NaN
# 178577                                                NaN
# 178578                                                NaN
# 178579                                                  Y
# 178580                                                  Y
#
#         ATTRIBUTES_COREDEMOGRAPHICS_DOB ATTRIBUTES_COREDEMOGRAPHICS_GENDER  \
# 0                              197010.0                                  M
# 1                              194702.0                                  M
# 2                              196410.0                                  F
# 3                                   NaN                                  F
# 4                              197009.0                                  M
# ...                                 ...                                ...
# 178576                         198903.0                                  F
# 178577                         195808.0                                  F
# 178578                         194204.0                                  M
# 178579                         196704.0                                  F
# 178580                         195709.0                                  M
#
#        ATTRIBUTES_COREDEMOGRAPHICS_MARRIEDCD  \
# 0                                          M
# 1                                        NaN
# 2                                          M
# 3                                        NaN
# 4                                          S
# ...                                      ...
# 178576                                     S
# 178577                                     M
# 178578                                     S
# 178579                                     M
# 178580                                     M
#
#        ATTRIBUTES_COREDEMOGRAPHICS_WEALTHSCR  \
# 0                                          A
# 1                                        NaN
# 2                                          E
# 3                                        NaN
# 4                                          D
# ...                                      ...
# 178576                                     A
# 178577                                     M
# 178578                                     H
# 178579                                     J
# 178580                                     M
#
#        ATTRIBUTES_COREDEMOGRAPHICS_HOMEOWNERCD  ...  \
# 0                                            H  ...
# 1                                          NaN  ...
# 2                                            H  ...
# 3                                          NaN  ...
# 4                                            U  ...
# ...                                        ...  ...
# 178576                                       H  ...
# 178577                                       H  ...
# 178578                                       H  ...
# 178579                                       H  ...
# 178580                                       H  ...
#
#        ATTRIBUTES_CONNEXSEGMENTATION_CT_ONLINESHOPSEG_DEALSEEK  \
# 0                                                       Y
# 1                                                     NaN
# 2                                                       Y
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 178576                                                NaN
# 178577                                                  Y
# 178578                                                NaN
# 178579                                                NaN
# 178580                                                NaN
#
#        ATTRIBUTES_CONNEXSEGMENTATION_CT_ONLINESHOPSEG_OFFLINE  \
# 0                                                       Y
# 1                                                     NaN
# 2                                                       Y
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 178576                                                NaN
# 178577                                                NaN
# 178578                                                NaN
# 178579                                                NaN
# 178580                                                NaN
#
#        ATTRIBUTES_CONNEXSEGMENTATION_CT_ONLINESHOPSEG_QUALSEEK  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                       Y
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 178576                                                NaN
# 178577                                                  Y
# 178578                                                NaN
# 178579                                                  Y
# 178580                                                  Y
#
#        ATTRIBUTES_CONNEXSEGMENTATION_CT_ONLINESHOPSEG_STRAITFWD  \
# 0                                                       Y
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 178576                                                NaN
# 178577                                                NaN
# 178578                                                NaN
# 178579                                                  Y
# 178580                                                NaN
#
#        ATTRIBUTES_CONNEXSEGMENTATION_CT_ONLINESHOPSEG_TRAD  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 178576                                                  Y
# 178577                                                NaN
# 178578                                                NaN
# 178579                                                NaN
# 178580                                                NaN
#
#         ATTRIBUTES_CONNEXSEGMENTATION_CT_MEDIA_HEAVYUSAGE_INTERNET  \
# 0                                                       Y
# 1                                                     NaN
# 2                                                       Y
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 178576                                                  Y
# 178577                                                NaN
# 178578                                                  Y
# 178579                                                NaN
# 178580                                                NaN
#
#         ATTRIBUTES_CONNEXSEGMENTATION_CT_MEDIA_HEAVYUSAGE_MAGAZINE  \
# 0                                                       Y
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 178576                                                NaN
# 178577                                                NaN
# 178578                                                  Y
# 178579                                                NaN
# 178580                                                  Y
#
#         ATTRIBUTES_CONNEXSEGMENTATION_CT_MEDIA_HEAVYUSAGE_NEWSPAPER  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 178576                                                NaN
# 178577                                                NaN
# 178578                                                NaN
# 178579                                                NaN
# 178580                                                NaN
#
#         ATTRIBUTES_CONNEXSEGMENTATION_CT_MEDIA_HEAVYUSAGE_RADIO  \
# 0                                                       Y
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                       Y
# ...                                                   ...
# 178576                                                  Y
# 178577                                                NaN
# 178578                                                NaN
# 178579                                                NaN
# 178580                                                NaN
#
#        ATTRIBUTES_CONNEXSEGMENTATION_CT_MEDIA_HEAVYUSAGE_TV
# 0                                                     NaN
# 1                                                     NaN
# 2                                                       Y
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 178576                                                NaN
# 178577                                                NaN
# 178578                                                NaN
# 178579                                                NaN
# 178580                                                NaN
#
# [178581 rows x 37 columns]

# %%
leads_dataset
# Out:
#                              HASHED_PHONE_NUMBER IS_APPOINTMENT_SET  \
# 0       16bc446a779996bf3007065819f1dd4692a17d14               True
# 1       6d30f0d0f87d39f8c178e3750072eef79bb9d7a0              False
# 2       9de207ef32d3696829ae369c2a9a4500cd36ec43               True
# 3       31bb43ece722562df3a163ba94be4eb2ccd1bf71              False
# 4       674de0e7b4da1c9945422b248f94cbf2499d59e2              False
# ...                                          ...                ...
# 308955  85580be57f0c2e3785ffe5b6187441487915513b               True
# 308956  8e7eed2ca3dd2e5a0f27fb3288e0157471a5f81b              False
# 308957  f1864c915f0cdf097a794f50a027f84af31f79b2              False
# 308958  e69897a60b18857a0e63558f3a86051321f16acf              False
# 308959  8ec10b82feb02dcd46151be3e340e64b7910634b              False
#
#          LEAD_CREATED_AT_UTC  ZIP_CODE              CITY STATE      COUNTY  \
# 0       2023-07-18T15:11:55Z   61080.0      South Beloit    IL   Winnebago
# 1       2022-09-19T18:37:21Z   33914.0        Cape Coral    FL         Lee
# 2       2022-11-09T21:38:10Z   42055.0           Kuttawa    KY        Lyon
# 3       2022-11-13T15:41:31Z   43701.0        Zanesville    OH   Muskingum
# 4       2022-10-07T17:56:51Z   22206.0         Arlington    VA   Arlington
# ...                      ...       ...               ...   ...         ...
# 308955  2023-07-10T13:55:13Z    2151.0            Revere    MA     Suffolk
# 308956  2023-05-12T13:54:23Z    3867.0         Rochester    NH   Strafford
# 308957  2023-04-25T20:08:59Z   89084.0   North Las Vegas    NV       Clark
# 308958  2023-02-02T20:22:57Z   44663.0  New Philadelphia    OH  Tuscarawas
# 308959  2023-01-19T18:33:11Z   44134.0         Cleveland    OH    Cuyahoga
#
#        EMAIL_DOMAIN OPERATINGSYSTEMCLASS OPERATINGSYSTEMNAME  ...  \
# 0         gmail.com               Mobile             Android  ...
# 1         gmail.com               Mobile                 iOS  ...
# 2         gmail.com               Mobile             Android  ...
# 3         gmail.com               Mobile                 iOS  ...
# 4         gmail.com               Mobile                 iOS  ...
# ...             ...                  ...                 ...  ...
# 308955    yahoo.com               Mobile                 iOS  ...
# 308956   icloud.com              Desktop              Mac OS  ...
# 308957     juno.com               Mobile             Android  ...
# 308958     live.com               Mobile             Android  ...
# 308959    gmail.com               Mobile             Android  ...
#
#        AGENTVERSIONMAJOR DEVICEBRAND DEVICEFIRMWAREVERSION  \
# 0                    114     Samsung                   NaN
# 1                    605       Apple                 19G71
# 2                    105     Samsung                   NaN
# 3                    605       Apple                 19G82
# 4                    605       Apple                20A380
# ...                  ...         ...                   ...
# 308955               114       Apple                15E148
# 308956                16       Apple                   NaN
# 308957               112     Samsung                   NaN
# 308958               104     Samsung                   NaN
# 308959               108    Motorola                   NaN
#
#                              DEVICENAME      DEVICEVERSION  \
# 0                      Samsung SM-A546V                NaN
# 1                          Apple iPhone  iPhone 13 Pro Max
# 2                      Samsung SM-G991U                NaN
# 3                          Apple iPhone          iPhone 13
# 4                          Apple iPhone          iPhone XR
# ...                                 ...                ...
# 308955                     Apple iPhone             iPhone
# 308956                  Apple Macintosh                NaN
# 308957                 Samsung SM-G981V                NaN
# 308958                 Samsung SM-S901U                NaN
# 308959  Motorola Edge Plus 5G UW (2022)                NaN
#
#        FACEBOOKDEVICECLASS LAYOUTENGINENAME NETWORKTYPE  \
# 0                      NaN            Blink     Unknown
# 1                    phone      AppleWebKit     Unknown
# 2                      NaN            Blink     Unknown
# 3                    phone      AppleWebKit     Unknown
# 4                    phone      AppleWebKit     Unknown
# ...                    ...              ...         ...
# 308955                 NaN      AppleWebKit     Unknown
# 308956                 NaN      AppleWebKit     Unknown
# 308957                 NaN            Blink     Unknown
# 308958                 NaN            Blink     Unknown
# 308959                 NaN            Blink     Unknown
#
#        OPERATINGSYSTEMVERSIONMAJOR            WEBVIEWAPPNAME
# 0                               13                 Newsbreak
# 1                               15      Facebook App for iOS
# 2                               12  Facebook App for Android
# 3                               15      Facebook App for iOS
# 4                               16      Facebook App for iOS
# ...                            ...                       ...
# 308955                          16                   Unknown
# 308956                       10.15                   Unknown
# 308957                          13  Facebook App for Android
# 308958                          13                   Unknown
# 308959                          12                   Unknown
#
# [305859 rows x 22 columns]

# %%
zip_code_dataset
# Out:
#        ZIP_CODE  Alchemist  Ancient Apparition  Anti-Mage   Axe  Batrider  \
# 0       47327.0     2065.0              1403.0       40.5  42.1      18.0
# 1       71268.0      347.0               257.0       40.6  40.6      17.0
# 2       27828.0     3581.0              2519.0       39.2  38.8      17.0
# 3       30143.0     7863.0              5681.0       46.4  49.5      27.0
# 4       25564.0       90.0                77.0       37.4  36.8      20.0
# ...         ...        ...                 ...        ...   ...       ...
# 19687   26711.0       39.0                26.0       42.8  44.2      19.0
# 19688   43338.0     1002.0               835.0       39.2  40.0      18.0
# 19689   94941.0    13144.0              8479.0       44.3  47.7      21.0
# 19690   46392.0     1354.0              1068.0       38.5  38.1      16.0
# 19691   76802.0      816.0               555.0       37.3  35.4      15.0
#
#        Beastmaster  Chaos Knight  Chen  Clinkz  ...  Dragon Knight  \
# 0              7.0          93.0  62.0    26.0  ...         1081.0
# 1              7.0          93.0  62.0    34.0  ...         1205.0
# 2             10.0          90.0  59.0    29.0  ...         1533.0
# 3              2.0          98.0  75.0    29.0  ...         2654.0
# 4              2.0          98.0  77.0    16.0  ...         1545.0
# ...            ...           ...   ...     ...  ...            ...
# 19687          5.0          95.0  69.0    26.0  ...         1886.0
# 19688          4.0          96.0  69.0    39.0  ...         1412.0
# 19689          4.0          96.0  64.0    22.0  ...        16373.0
# 19690          3.0          97.0  79.0    40.0  ...         1708.0
# 19691          3.0          97.0  70.0    29.0  ...         1379.0
#
#        Drow Ranger  Earth Spirit  Earthshaker  Elder Titan  Ember Spirit  \
# 0            840.0          16.0         14.0         25.0          12.0
# 1            910.0          21.0         21.0         31.0          16.0
# 2           1288.0          24.0         20.0         34.0          21.0
# 3           2445.0           9.0          9.0         14.0           9.0
# 4           1125.0           0.0         22.0          0.0           0.0
# ...            ...           ...          ...          ...           ...
# 19687       1906.0          23.0         13.0         33.0          18.0
# 19688       1287.0          10.0          7.0         13.0           6.0
# 19689      14479.0           5.0          5.0          3.0           1.0
# 19690       1586.0           7.0          8.0          8.0           6.0
# 19691       1260.0          11.0         11.0         12.0           5.0
#
#        Enchantress  Enigma  Faceless Void   Pudge
# 0             76.0    83.0            3.0  1952.0
# 1             90.0    74.0            0.0  1991.0
# 2             68.0    73.0            3.0  1990.0
# 3             79.0    84.0            1.0  1994.0
# 4             80.0    68.0            0.0  1987.0
# ...            ...     ...            ...     ...
# 19687         77.0    86.0            0.0  1992.0
# 19688         84.0    80.0            0.0  1984.0
# 19689         69.0    80.0            3.0  1962.0
# 19690         81.0    85.0            5.0  1991.0
# 19691         79.0    71.0            0.0  1981.0
#
# [19692 rows x 26 columns]

# %% [markdown]
# Given the objective of predicting *IS_APPOINTMENT_SET*, a Left Join of the leads_dataset with the infutor_enrichment_dataset using HASHED_PHONE_NUMBER as the key seems to be the most suitable. This will ensure that all leads are kept in the analysis, enriching them with additional data when available.

# %%
merged_dataset = pd.merge(leads_dataset, infutor_dataset, on='HASHED_PHONE_NUMBER', how='left')
full_dataset = pd.merge(merged_dataset, zip_code_dataset, on='ZIP_CODE', how='left')

# %%
full_dataset
# Out:
#                              HASHED_PHONE_NUMBER IS_APPOINTMENT_SET  \
# 0       16bc446a779996bf3007065819f1dd4692a17d14               True
# 1       6d30f0d0f87d39f8c178e3750072eef79bb9d7a0              False
# 2       9de207ef32d3696829ae369c2a9a4500cd36ec43               True
# 3       31bb43ece722562df3a163ba94be4eb2ccd1bf71              False
# 4       674de0e7b4da1c9945422b248f94cbf2499d59e2              False
# ...                                          ...                ...
# 331682  85580be57f0c2e3785ffe5b6187441487915513b               True
# 331683  8e7eed2ca3dd2e5a0f27fb3288e0157471a5f81b              False
# 331684  f1864c915f0cdf097a794f50a027f84af31f79b2              False
# 331685  e69897a60b18857a0e63558f3a86051321f16acf              False
# 331686  8ec10b82feb02dcd46151be3e340e64b7910634b              False
#
#          LEAD_CREATED_AT_UTC  ZIP_CODE              CITY STATE      COUNTY  \
# 0       2023-07-18T15:11:55Z   61080.0      South Beloit    IL   Winnebago
# 1       2022-09-19T18:37:21Z   33914.0        Cape Coral    FL         Lee
# 2       2022-11-09T21:38:10Z   42055.0           Kuttawa    KY        Lyon
# 3       2022-11-13T15:41:31Z   43701.0        Zanesville    OH   Muskingum
# 4       2022-10-07T17:56:51Z   22206.0         Arlington    VA   Arlington
# ...                      ...       ...               ...   ...         ...
# 331682  2023-07-10T13:55:13Z    2151.0            Revere    MA     Suffolk
# 331683  2023-05-12T13:54:23Z    3867.0         Rochester    NH   Strafford
# 331684  2023-04-25T20:08:59Z   89084.0   North Las Vegas    NV       Clark
# 331685  2023-02-02T20:22:57Z   44663.0  New Philadelphia    OH  Tuscarawas
# 331686  2023-01-19T18:33:11Z   44134.0         Cleveland    OH    Cuyahoga
#
#        EMAIL_DOMAIN OPERATINGSYSTEMCLASS OPERATINGSYSTEMNAME  ...  \
# 0         gmail.com               Mobile             Android  ...
# 1         gmail.com               Mobile                 iOS  ...
# 2         gmail.com               Mobile             Android  ...
# 3         gmail.com               Mobile                 iOS  ...
# 4         gmail.com               Mobile                 iOS  ...
# ...             ...                  ...                 ...  ...
# 331682    yahoo.com               Mobile                 iOS  ...
# 331683   icloud.com              Desktop              Mac OS  ...
# 331684     juno.com               Mobile             Android  ...
# 331685     live.com               Mobile             Android  ...
# 331686    gmail.com               Mobile             Android  ...
#
#        Dragon Knight Drow Ranger Earth Spirit Earthshaker Elder Titan  \
# 0             1385.0      1244.0          7.0        10.0        13.0
# 1             3253.0      2845.0          9.0         8.0        15.0
# 2             1400.0      1098.0         16.0         6.0        31.0
# 3             1464.0      1140.0         20.0        18.0        33.0
# 4             4399.0      4375.0          4.0         3.0         4.0
# ...              ...         ...          ...         ...         ...
# 331682        3733.0      3749.0         13.0        13.0        18.0
# 331683        2101.0      1775.0         10.0        11.0        12.0
# 331684        2721.0      3098.0          6.0         7.0         7.0
# 331685        1316.0      1245.0         18.0        19.0        39.0
# 331686        1314.0      1113.0          7.0         7.0         8.0
#
#        Ember Spirit Enchantress Enigma Faceless Void   Pudge
# 0               4.0        71.0   87.0           3.0  1984.0
# 1               6.0        78.0   83.0           3.0  1998.0
# 2              12.0        91.0   60.0           0.0  1981.0
# 3              23.0        63.0   72.0           4.0  1964.0
# 4               2.0        55.0   45.0           1.0  1948.0
# ...             ...         ...    ...           ...     ...
# 331682         14.0        51.0   35.0          27.0  1953.0
# 331683         14.0        67.0   56.0           6.0  1975.0
# 331684          7.0        68.0   87.0           0.0  2005.0
# 331685         15.0        57.0   65.0           8.0  1967.0
# 331686         11.0        74.0   84.0           4.0  1957.0
#
# [331687 rows x 83 columns]

# %% [markdown]
# ### 2.1 - Columns process
# #### 2.1.1 - Remove columns with more than 70% of nulls

# %%
null_percentage = full_dataset.isnull().mean() * 100
cols_to_keep = null_percentage[null_percentage < 70].index
clean_full_dataset = full_dataset[cols_to_keep]

clean_full_dataset.drop(columns=['Unnamed: 0'], inplace=True)

# %%
clean_full_dataset.columns
# Out:
# Index(['HASHED_PHONE_NUMBER', 'IS_APPOINTMENT_SET', 'LEAD_CREATED_AT_UTC',
#        'ZIP_CODE', 'CITY', 'STATE', 'COUNTY', 'EMAIL_DOMAIN',
#        'OPERATINGSYSTEMCLASS', 'OPERATINGSYSTEMNAME', 'AGENTLANGUAGECODE',
#        'AGENTNAME', 'AGENTVERSIONMAJOR', 'DEVICEBRAND',
#        'DEVICEFIRMWAREVERSION', 'DEVICENAME', 'DEVICEVERSION',
#        'LAYOUTENGINENAME', 'NETWORKTYPE', 'OPERATINGSYSTEMVERSIONMAJOR',
#        'WEBVIEWAPPNAME', 'MATCHLEVEL', 'ATTRIBUTES_COREDEMOGRAPHICS_DOB',
#        'ATTRIBUTES_COREDEMOGRAPHICS_GENDER',
#        'ATTRIBUTES_COREDEMOGRAPHICS_MARRIEDCD',
#        'ATTRIBUTES_COREDEMOGRAPHICS_WEALTHSCR',
#        'ATTRIBUTES_COREDEMOGRAPHICS_HOMEOWNERCD',
#        'ATTRIBUTES_COREDEMOGRAPHICS_EHI',
#        'ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_CREDITCARD',
#        'ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_YRBLD',
#        'ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_LOR',
#        'ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_HHNBR',
#        'ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_CENS_POP_DENSITY', 'Alchemist',
#        'Ancient Apparition', 'Anti-Mage', 'Axe', 'Batrider', 'Beastmaster',
#        'Chaos Knight', 'Chen', 'Clinkz', 'Clockwerk', 'Crystal Maiden',
#        'Dark Seer', 'Dazzle', 'Death Prophet', 'Doom', 'Dragon Knight',
#        'Drow Ranger', 'Earth Spirit', 'Earthshaker', 'Elder Titan',
#        'Ember Spirit', 'Enchantress', 'Enigma', 'Faceless Void', 'Pudge'],
#       dtype='object')

# %%
numeric_columns = clean_full_dataset.select_dtypes(include=['number']).columns
numeric_columns = [item for item in numeric_columns if item not in ['ZIP_CODE', 'Unnamed: 0']]
categorical_columns = clean_full_dataset.select_dtypes(exclude=['number']).columns

numeric_columns = list(numeric_columns)
categorical_columns = list(categorical_columns)
categorical_columns.append('ZIP_CODE')

#Convert all categorical columns as string
clean_full_dataset[categorical_columns] = clean_full_dataset[categorical_columns].astype(str)

# %%
numeric_columns
# Out:
# ['MATCHLEVEL',
#  'ATTRIBUTES_COREDEMOGRAPHICS_DOB',
#  'ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_YRBLD',
#  'ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_LOR',
#  'ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_HHNBR',
#  'ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_CENS_POP_DENSITY',
#  'Alchemist',
#  'Ancient Apparition',
#  'Anti-Mage',
#  'Axe',
#  'Batrider',
#  'Beastmaster',
#  'Chaos Knight',
#  'Chen',
#  'Clinkz',
#  'Clockwerk',
#  'Crystal Maiden',
#  'Dark Seer',
#  'Dazzle',
#  'Death Prophet',
#  'Doom',
#  'Dragon Knight',
#  'Drow Ranger',
#  'Earth Spirit',
#  'Earthshaker',
#  'Elder Titan',
#  'Ember Spirit',
#  'Enchantress',
#  'Enigma',
#  'Faceless Void',
#  'Pudge']

# %%
categorical_columns
# Out:
# ['HASHED_PHONE_NUMBER',
#  'IS_APPOINTMENT_SET',
#  'LEAD_CREATED_AT_UTC',
#  'CITY',
#  'STATE',
#  'COUNTY',
#  'EMAIL_DOMAIN',
#  'OPERATINGSYSTEMCLASS',
#  'OPERATINGSYSTEMNAME',
#  'AGENTLANGUAGECODE',
#  'AGENTNAME',
#  'AGENTVERSIONMAJOR',
#  'DEVICEBRAND',
#  'DEVICEFIRMWAREVERSION',
#  'DEVICENAME',
#  'DEVICEVERSION',
#  'LAYOUTENGINENAME',
#  'NETWORKTYPE',
#  'OPERATINGSYSTEMVERSIONMAJOR',
#  'WEBVIEWAPPNAME',
#  'ATTRIBUTES_COREDEMOGRAPHICS_GENDER',
#  'ATTRIBUTES_COREDEMOGRAPHICS_MARRIEDCD',
#  'ATTRIBUTES_COREDEMOGRAPHICS_WEALTHSCR',
#  'ATTRIBUTES_COREDEMOGRAPHICS_HOMEOWNERCD',
#  'ATTRIBUTES_COREDEMOGRAPHICS_EHI',
#  'ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_CREDITCARD',
#  'ZIP_CODE']

# %%
clean_full_dataset
# Out:
#                              HASHED_PHONE_NUMBER IS_APPOINTMENT_SET  \
# 0       16bc446a779996bf3007065819f1dd4692a17d14               True
# 1       6d30f0d0f87d39f8c178e3750072eef79bb9d7a0              False
# 2       9de207ef32d3696829ae369c2a9a4500cd36ec43               True
# 3       31bb43ece722562df3a163ba94be4eb2ccd1bf71              False
# 4       674de0e7b4da1c9945422b248f94cbf2499d59e2              False
# ...                                          ...                ...
# 331682  85580be57f0c2e3785ffe5b6187441487915513b               True
# 331683  8e7eed2ca3dd2e5a0f27fb3288e0157471a5f81b              False
# 331684  f1864c915f0cdf097a794f50a027f84af31f79b2              False
# 331685  e69897a60b18857a0e63558f3a86051321f16acf              False
# 331686  8ec10b82feb02dcd46151be3e340e64b7910634b              False
#
#          LEAD_CREATED_AT_UTC ZIP_CODE              CITY STATE      COUNTY  \
# 0       2023-07-18T15:11:55Z  61080.0      South Beloit    IL   Winnebago
# 1       2022-09-19T18:37:21Z  33914.0        Cape Coral    FL         Lee
# 2       2022-11-09T21:38:10Z  42055.0           Kuttawa    KY        Lyon
# 3       2022-11-13T15:41:31Z  43701.0        Zanesville    OH   Muskingum
# 4       2022-10-07T17:56:51Z  22206.0         Arlington    VA   Arlington
# ...                      ...      ...               ...   ...         ...
# 331682  2023-07-10T13:55:13Z   2151.0            Revere    MA     Suffolk
# 331683  2023-05-12T13:54:23Z   3867.0         Rochester    NH   Strafford
# 331684  2023-04-25T20:08:59Z  89084.0   North Las Vegas    NV       Clark
# 331685  2023-02-02T20:22:57Z  44663.0  New Philadelphia    OH  Tuscarawas
# 331686  2023-01-19T18:33:11Z  44134.0         Cleveland    OH    Cuyahoga
#
#        EMAIL_DOMAIN OPERATINGSYSTEMCLASS OPERATINGSYSTEMNAME  ...  \
# 0         gmail.com               Mobile             Android  ...
# 1         gmail.com               Mobile                 iOS  ...
# 2         gmail.com               Mobile             Android  ...
# 3         gmail.com               Mobile                 iOS  ...
# 4         gmail.com               Mobile                 iOS  ...
# ...             ...                  ...                 ...  ...
# 331682    yahoo.com               Mobile                 iOS  ...
# 331683   icloud.com              Desktop              Mac OS  ...
# 331684     juno.com               Mobile             Android  ...
# 331685     live.com               Mobile             Android  ...
# 331686    gmail.com               Mobile             Android  ...
#
#        Dragon Knight Drow Ranger Earth Spirit Earthshaker Elder Titan  \
# 0             1385.0      1244.0          7.0        10.0        13.0
# 1             3253.0      2845.0          9.0         8.0        15.0
# 2             1400.0      1098.0         16.0         6.0        31.0
# 3             1464.0      1140.0         20.0        18.0        33.0
# 4             4399.0      4375.0          4.0         3.0         4.0
# ...              ...         ...          ...         ...         ...
# 331682        3733.0      3749.0         13.0        13.0        18.0
# 331683        2101.0      1775.0         10.0        11.0        12.0
# 331684        2721.0      3098.0          6.0         7.0         7.0
# 331685        1316.0      1245.0         18.0        19.0        39.0
# 331686        1314.0      1113.0          7.0         7.0         8.0
#
#        Ember Spirit Enchantress Enigma Faceless Void   Pudge
# 0               4.0        71.0   87.0           3.0  1984.0
# 1               6.0        78.0   83.0           3.0  1998.0
# 2              12.0        91.0   60.0           0.0  1981.0
# 3              23.0        63.0   72.0           4.0  1964.0
# 4               2.0        55.0   45.0           1.0  1948.0
# ...             ...         ...    ...           ...     ...
# 331682         14.0        51.0   35.0          27.0  1953.0
# 331683         14.0        67.0   56.0           6.0  1975.0
# 331684          7.0        68.0   87.0           0.0  2005.0
# 331685         15.0        57.0   65.0           8.0  1967.0
# 331686         11.0        74.0   84.0           4.0  1957.0
#
# [331687 rows x 58 columns]

# %% [markdown]
# ## 3.0 - Exploratory Data Analysis

# %%
clean_full_dataset.describe()
# Out:
#           MATCHLEVEL  ATTRIBUTES_COREDEMOGRAPHICS_DOB  \
# count  213159.000000                    177486.000000
# mean        1.829554                    195034.137526
# std         1.603779                     14914.785313
# min         1.000000                      1911.000000
# 25%         1.000000                    195011.000000
# 50%         1.000000                    196012.000000
# 75%         1.000000                    197208.000000
# max         6.000000                    202003.000000
#
#        ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_YRBLD  \
# count                              137983.000000
# mean                                 1977.059442
# std                                    27.733550
# min                                  1700.000000
# 25%                                  1961.000000
# 50%                                  1982.000000
# 75%                                  1998.000000
# max                                  2022.000000
#
#        ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_LOR  \
# count                            165401.000000
# mean                                 11.012624
# std                                   5.153583
# min                                   0.000000
# 25%                                   7.000000
# 50%                                  13.000000
# 75%                                  15.000000
# max                                  25.000000
#
#        ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_HHNBR  \
# count                              165406.000000
# mean                                    3.178555
# std                                     1.623452
# min                                     1.000000
# 25%                                     2.000000
# 50%                                     3.000000
# 75%                                     4.000000
# max                                     9.000000
#
#        ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_CENS_POP_DENSITY      Alchemist  \
# count                                      164233.000000     331648.000000
# mean                                         2134.502037      10207.032706
# std                                          4058.175882       6576.850911
# min                                             0.000000          0.000000
# 25%                                           294.000000       5121.000000
# 50%                                          1081.000000       9560.000000
# 75%                                          2717.000000      14444.000000
# max                                        148228.000000      35109.000000
#
#        Ancient Apparition      Anti-Mage            Axe  ...  Dragon Knight  \
# count       331648.000000  331648.000000  331648.000000  ...  331648.000000
# mean          6789.432263      39.723074      39.562259  ...    2502.184919
# std           4575.477565       4.877356       6.760431  ...    1825.876931
# min              0.000000       0.000000       0.000000  ...       0.000000
# 25%           3331.000000      37.000000      35.600000  ...    1519.000000
# 50%           6275.000000      39.400000      39.100000  ...    2041.000000
# 75%           9370.000000      41.900000      42.800000  ...    2941.000000
# max          25779.000000      87.500000      69.700000  ...   71784.000000
#
#          Drow Ranger   Earth Spirit    Earthshaker    Elder Titan  \
# count  331648.000000  331648.000000  331648.000000  331648.000000
# mean     2242.640914      12.470556      12.010647      17.225037
# std      1613.992245       7.850258       7.142047      12.889894
# min         0.000000       0.000000       0.000000       0.000000
# 25%      1307.000000       7.000000       7.000000       7.000000
# 50%      1794.000000      11.000000      10.000000      14.000000
# 75%      2685.000000      17.000000      16.000000      24.000000
# max     24310.000000      81.000000      69.000000      99.000000
#
#         Ember Spirit    Enchantress         Enigma  Faceless Void  \
# count  331648.000000  331648.000000  331648.000000  331648.000000
# mean       11.154378      67.520196      72.860593       2.701557
# std         8.307021      14.771909      15.467290       3.754182
# min         0.000000       0.000000       0.000000       0.000000
# 25%         5.000000      59.000000      66.000000       1.000000
# 50%         9.000000      69.000000      75.000000       2.000000
# 75%        15.000000      78.000000      83.000000       4.000000
# max        72.000000      99.000000      99.000000      52.000000
#
#                Pudge
# count  331648.000000
# mean     1973.437548
# std        97.476871
# min         0.000000
# 25%      1966.000000
# 50%      1981.000000
# 75%      1992.000000
# max      2017.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# ### 3.1 - Check distribuition of numerical columns

# %%
for col in numeric_columns:
    
    plt.figure(figsize=(10, 6))
    sns.histplot(clean_full_dataset[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
total_columns = len(numeric_columns)
rows = 7
columns_per_row = -(-total_columns // rows)

plt.figure(figsize=(25, 20))

# Criando os boxplots em 4 linhas
for i, var in enumerate(numeric_columns, start=1):
    plt.subplot(rows, columns_per_row, i)
    sns.boxplot(y=var, data=clean_full_dataset)
    plt.title(f'Boxplot {var}')

plt.tight_layout()
plt.show()

# %%
threshold = 0.5
corr_matrix = clean_full_dataset[numeric_columns].corr()
corr_pairs = corr_matrix.unstack()
high_corr_pairs = corr_pairs[(abs(corr_pairs) > threshold) & (abs(corr_pairs) < 1)]

high_corr_vars = list(set([item[0] for item in high_corr_pairs.index] + [item[1] for item in high_corr_pairs.index]))

filtered_high_corr_matrix = clean_full_dataset[high_corr_vars].corr()

plt.figure(figsize=(25, 8))
sns.heatmap(filtered_high_corr_matrix, annot=True, cmap='coolwarm', linewidths=.5, cbar_kws={"shrink": .5})
plt.title('Correlation Matrix for Variables with High Correlation')
plt.show()

# %% [markdown]
# ## 4.0 - Data processing
# ### 4.1 Null filling

# %%
for col in numeric_columns:
    clean_full_dataset[col].fillna(clean_full_dataset[col].median(), inplace=True)

for col in categorical_columns:
    clean_full_dataset[col].fillna("MISSING", inplace=True)

# %%
clean_full_dataset
# Out:
#                              HASHED_PHONE_NUMBER IS_APPOINTMENT_SET  \
# 0       16bc446a779996bf3007065819f1dd4692a17d14               True
# 1       6d30f0d0f87d39f8c178e3750072eef79bb9d7a0              False
# 2       9de207ef32d3696829ae369c2a9a4500cd36ec43               True
# 3       31bb43ece722562df3a163ba94be4eb2ccd1bf71              False
# 4       674de0e7b4da1c9945422b248f94cbf2499d59e2              False
# ...                                          ...                ...
# 331682  85580be57f0c2e3785ffe5b6187441487915513b               True
# 331683  8e7eed2ca3dd2e5a0f27fb3288e0157471a5f81b              False
# 331684  f1864c915f0cdf097a794f50a027f84af31f79b2              False
# 331685  e69897a60b18857a0e63558f3a86051321f16acf              False
# 331686  8ec10b82feb02dcd46151be3e340e64b7910634b              False
#
#          LEAD_CREATED_AT_UTC ZIP_CODE              CITY STATE      COUNTY  \
# 0       2023-07-18T15:11:55Z  61080.0      South Beloit    IL   Winnebago
# 1       2022-09-19T18:37:21Z  33914.0        Cape Coral    FL         Lee
# 2       2022-11-09T21:38:10Z  42055.0           Kuttawa    KY        Lyon
# 3       2022-11-13T15:41:31Z  43701.0        Zanesville    OH   Muskingum
# 4       2022-10-07T17:56:51Z  22206.0         Arlington    VA   Arlington
# ...                      ...      ...               ...   ...         ...
# 331682  2023-07-10T13:55:13Z   2151.0            Revere    MA     Suffolk
# 331683  2023-05-12T13:54:23Z   3867.0         Rochester    NH   Strafford
# 331684  2023-04-25T20:08:59Z  89084.0   North Las Vegas    NV       Clark
# 331685  2023-02-02T20:22:57Z  44663.0  New Philadelphia    OH  Tuscarawas
# 331686  2023-01-19T18:33:11Z  44134.0         Cleveland    OH    Cuyahoga
#
#        EMAIL_DOMAIN OPERATINGSYSTEMCLASS OPERATINGSYSTEMNAME  ...  \
# 0         gmail.com               Mobile             Android  ...
# 1         gmail.com               Mobile                 iOS  ...
# 2         gmail.com               Mobile             Android  ...
# 3         gmail.com               Mobile                 iOS  ...
# 4         gmail.com               Mobile                 iOS  ...
# ...             ...                  ...                 ...  ...
# 331682    yahoo.com               Mobile                 iOS  ...
# 331683   icloud.com              Desktop              Mac OS  ...
# 331684     juno.com               Mobile             Android  ...
# 331685     live.com               Mobile             Android  ...
# 331686    gmail.com               Mobile             Android  ...
#
#        Dragon Knight Drow Ranger Earth Spirit Earthshaker Elder Titan  \
# 0             1385.0      1244.0          7.0        10.0        13.0
# 1             3253.0      2845.0          9.0         8.0        15.0
# 2             1400.0      1098.0         16.0         6.0        31.0
# 3             1464.0      1140.0         20.0        18.0        33.0
# 4             4399.0      4375.0          4.0         3.0         4.0
# ...              ...         ...          ...         ...         ...
# 331682        3733.0      3749.0         13.0        13.0        18.0
# 331683        2101.0      1775.0         10.0        11.0        12.0
# 331684        2721.0      3098.0          6.0         7.0         7.0
# 331685        1316.0      1245.0         18.0        19.0        39.0
# 331686        1314.0      1113.0          7.0         7.0         8.0
#
#        Ember Spirit Enchantress Enigma Faceless Void   Pudge
# 0               4.0        71.0   87.0           3.0  1984.0
# 1               6.0        78.0   83.0           3.0  1998.0
# 2              12.0        91.0   60.0           0.0  1981.0
# 3              23.0        63.0   72.0           4.0  1964.0
# 4               2.0        55.0   45.0           1.0  1948.0
# ...             ...         ...    ...           ...     ...
# 331682         14.0        51.0   35.0          27.0  1953.0
# 331683         14.0        67.0   56.0           6.0  1975.0
# 331684          7.0        68.0   87.0           0.0  2005.0
# 331685         15.0        57.0   65.0           8.0  1967.0
# 331686         11.0        74.0   84.0           4.0  1957.0
#
# [331687 rows x 58 columns]

# %% [markdown]
# ### 4.2 Ecoding Data

# %%
clean_full_dataset = clean_full_dataset.drop(columns=['HASHED_PHONE_NUMBER'])

X = clean_full_dataset.drop(columns=['IS_APPOINTMENT_SET'])
y = clean_full_dataset['IS_APPOINTMENT_SET'].map({'True': 1, 'False': 0})

# %%
# Standardizing numeric variables between 0 and 1

scaler = MinMaxScaler()
X[numeric_columns] = scaler.fit_transform(X[numeric_columns])

# %%
categorical_columns.remove('HASHED_PHONE_NUMBER')
categorical_columns.remove('IS_APPOINTMENT_SET')

# Applying LabelEncoder to categorical variables
label_encoder = LabelEncoder()

for col in categorical_columns:
    X[col] = label_encoder.fit_transform(X[col])

# %% [markdown]
# ### 4.3 - Check unbalance proportion

# %%
def show_proportion_binary_var(y):

    counts = y.value_counts()

    # Plota o gráfico de barras
    plt.bar(counts.index, counts.values)
    plt.xlabel('Classes')
    plt.ylabel('Number of Occurrences')
    plt.title('Binary Variable Balancing')
    plt.xticks(counts.index, ['Class 0', 'Class 1'])
    plt.show()
    
show_proportion_binary_var(y)

# %%
# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ### 4.3.1 - Data Balancing

# %%
adasyn = ADASYN(random_state=42)

mask = y_train.notna()  # Cria uma máscara para linhas não-NaN
X_train_clean = X_train[mask]
y_train_clean = y_train[mask]

# Applying ADASYN only to the training set to avoid information leakage to the test
X_resampled, y_resampled = adasyn.fit_resample(X_train_clean, y_train_clean)

# %%
show_proportion_binary_var(y_resampled)

# %% [markdown]
# ## 5.0 - Feature Engineering
# ### 5.1 - Selecting best features for the model automatically

# %%
forest = RandomForestClassifier(n_estimators=50, random_state=42, verbose=True)
forest.fit(X_resampled, y_resampled)
importances = forest.feature_importances_

# Ordering features by importance
indices = np.argsort(importances)[::-1]
sorted_features = [X_resampled.columns[i] for i in indices]
sorted_importances = importances[indices]
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:  1.7min finished

# %%
plt.figure(figsize=(12, 8))
plt.title('Importance of Features - Random Forest')
plt.bar(range(X_resampled.shape[1]), sorted_importances, color='skyblue', align='center')
plt.xticks(range(X_resampled.shape[1]), sorted_features, rotation=90)
plt.xlabel('Features')
plt.ylabel('Importance')
plt.tight_layout()
plt.show()

# %%
def run_feature_selection_experiment(X_train, y_train, X_test, y_test, feature_importances, n_iterations=10):
    indices = np.argsort(feature_importances)[::-1]
    
    #X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    results = []    
    for n_features in range(1, n_iterations + 1):

        selected_features = indices[:n_features]
        X_train_selected = X_train[:, selected_features]
        X_test_selected = X_test[:, selected_features]
        
        # Training the model with the current subset of features
        model = RandomForestClassifier(random_state=42)
        model.fit(X_train_selected, y_train)
        
        # Evaluating the model
        y_pred = model.predict(X_test_selected)
        score = balanced_accuracy_score(y_test, y_pred)
        
        results.append({'N_Features': n_features, 'Balanced_Accuracy': score})
    
    # Convertendo resultados em DataFrame para análise
    results_df = pd.DataFrame(results)
    
    return results_df

# %%
y_test.value_counts()
# Out:
# 0    82737
# 1    16770
# Name: IS_APPOINTMENT_SET, dtype: int64

# %%
results_df = run_feature_selection_experiment(X_resampled.values, 
                                              y_resampled, X_test.values, y_test,
                                              importances, n_iterations=X.shape[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File E:\Python311\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File E:\Python311\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File E:\Python311\Lib\site-packages\pandas\_libs\index.pyx:144, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), array([18], dtype=int64))' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 results_df = run_feature_selection_experiment(X_resampled.values,
#       2                                               y_resampled, X_test.values, y_test,
#       3                                               importances, n_iterations=X.shape[1])
#
# Cell In[39], line 10, in run_feature_selection_experiment(X, y, X_test, y_test, feature_importances, n_iterations)
#       7 for n_features in range(1, n_iterations + 1):
#       9     selected_features = indices[:n_features]
# ---> 10     X_train_selected = X_train[:, selected_features]
#      11     X_test_selected = X_test[:, selected_features]
#      13     # Training the model with the current subset of features
#
# File E:\Python311\Lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File E:\Python311\Lib\site-packages\pandas\core\indexes\base.py:3809, in Index.get_loc(self, key, method, tolerance)
#    3804         raise KeyError(key) from err
#    3805     except TypeError:
#    3806         # If we have a listlike key, _check_indexing_error will raise
#    3807         #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808         #  the TypeError.
# -> 3809         self._check_indexing_error(key)
#    3810         raise
#    3812 # GH#42269
#
# File E:\Python311\Lib\site-packages\pandas\core\indexes\base.py:5925, in Index._check_indexing_error(self, key)
#    5921 def _check_indexing_error(self, key):
#    5922     if not is_scalar(key):
#    5923         # if key is not a scalar, directly raise an error (the code below
#    5924         # would convert to numpy arrays and raise later any way) - GH29926
# -> 5925         raise InvalidIndexError(key)
#
# InvalidIndexError: (slice(None, None, None), array([18], dtype=int64))

# %% [markdown]
# ### 5.2 - Analysis of features used
#
# Analysis of the use of the most important features indicates that the use of the 25 most relevant features is sufficient to obtain the best results from the model.

# %%
plt.figure(figsize=(10, 6))
plt.plot(results_df['N_Features'], results_df['Balanced_Accuracy'], marker='o')
plt.title('Balanced Accuracy x Number of Features')
plt.xlabel('Number of Features')
plt.ylabel('Balanced Accuracy')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 5.2.1 - Most relevant features
#
# Below we have a list of the 20 most important features for the model

# %%
# Finding the optimal number of features
optimal_n_features = results_df.sort_values(by='Balanced_Accuracy', ascending=False).iloc[0]['N_Features']

best_features = np.argsort(importances)[::-1][:int(optimal_n_features)]
print("Best features:", X.columns[best_features].tolist())
best_features_names = X.columns[best_features].tolist()

# %% [markdown]
# ## 6.0 - Modeling

# %%
X_train = X_resampled.copy()
y_train = y_resampled.copy()

# %% [markdown]
# ### 6.1 - Testing with different classifiers

# %%
classifiers = {
    "XGBoost": xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss'),
    "Random Forest": RandomForestClassifier(random_state=42),
    "Gradient Boosting": GradientBoostingClassifier(random_state=42),
    "AdaBoost": AdaBoostClassifier(random_state=42),
    "Logistic Regression": LogisticRegression(max_iter=1000, random_state=42),
    "K-Nearest Neighbors": KNeighborsClassifier()
}

# %%
results = {}


for name, clf in classifiers.items():
    clf.fit(X_train[best_features_names], y_train)  # train classifier
    y_pred = clf.predict(X_test[best_features_names])
    score = balanced_accuracy_score(y_test, y_pred)
    results[name] = score
    print({'Algorithm': name, 'Score':score})

# %%
results_df = pd.DataFrame.from_dict(results, orient='index', columns=['Balanced Accuracy'])
results_df.sort_values(by='Balanced Accuracy', ascending=False, inplace=True)

# %%
results_df

# %%
# Identifying the champion algorithm based on the highest balanced accuracy
champion_algorithm = results_df.index[0]
champion_score = results_df.iloc[0]['Balanced Accuracy']

print(f"Champion algorithm: {champion_algorithm} with balanced accuracy {champion_score}")

# %% [markdown]
# ### 6.2 - Best Model: Random Forest

# %%
X_train = X_resampled.copy()
y_train = y_resampled.copy()

# Training the model with the current subset of features
model = RandomForestClassifier(random_state=42)
model.fit(X_train[best_features_names], y_train)

# Evaluating the model
y_pred = model.predict(X_test[best_features_names])
score = balanced_accuracy_score(y_test, y_pred)

# %%
score

# %% [markdown]
# ## 7.0 Results assessment

# %%
conf_mat = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ## 8.0 - What I would do if I had more time:
#
# * It would better investigate the imbalance of existing classes in the base
# * Would run a hyperparameter optimization algorithm on the champion algorithm
# * It would save the pre-trained model, as well as the base coding dictionary
# * Would carry out a more complete exploratory analysis
